# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# ex situ

labels = ['comment', 'où', 'quand', 'quiS', 'quiO', 'quoi0']
late1800 = [100, 100, 100, 100, 100, 100]
early_1900 = [100, 100, 100, 100, 100, 100]
eslo1 = [96, 76, 81, 100, 74, 61]
eslo2 = [68, 24, 52, 94, 30, 4]

x = np.arange(len(labels))  # the label locations
width = 0.20  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width*1.5, late1800, width, label='late 1800')
rects2 = ax.bar(x - width/2, early_1900, width, label='early 1900')
rects3 = ax.bar(x + width/2, eslo1, width, label='1970s')
rects4 = ax.bar(x + width*1.5, eslo2, width, label='2010s')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage of occurrences')
ax.set_title('Distribution of wh-ex situ constructions')
ax.set_xticks(x, labels)
ax.legend()

# ax.bar_label(rects1, padding=1)
# ax.bar_label(rects2, padding=1)
ax.bar_label(rects3, padding=1)
ax.bar_label(rects4, padding=1)

fig.tight_layout()

plt.show()

# %%
# in situ

labels = ['comment', 'où', 'quand', 'quiS', 'quiO', 'quoi0']
late1800 = [0, 0, 0, 0, 0, 0]
early_1900 = [0, 0, 0, 0, 0, 0]
eslo1 = [4, 24, 19, 0, 26, 39]
eslo2 = [32, 76, 48, 6, 70, 96]

x = np.arange(len(labels))  # the label locations
width = 0.20  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width*1.5, late1800, width, label='late 1800')
rects2 = ax.bar(x - width/2, early_1900, width, label='early 1900')
rects3 = ax.bar(x + width/2, eslo1, width, label='1970s')
rects4 = ax.bar(x + width*1.5, eslo2, width, label='2010s')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percentage of occurrences')
ax.set_title('Distribution of wh-in situ constructions')
ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rects1, padding=1)
ax.bar_label(rects2, padding=1)
ax.bar_label(rects3, padding=1)
ax.bar_label(rects4, padding=1)

fig.tight_layout()

plt.show()

# %%
# ex situ line

# create data
x = ['late 1800', 'early 1900', '1970s', '2010s']

# y axes
comment = [100, 100, 96, 68]
où = [100, 100, 76, 24]
quand = [100, 100, 81, 52]
quiS = [100, 100, 100, 94]
quiO = [100, 100, 74, 30]
quoiO = [100, 100, 61, 4]
  
# plot lines
plt.plot(x, comment, label = "comment", linestyle="-")
plt.plot(x, où, label = "où", linestyle="-")
plt.plot(x, quand, label = "quand", linestyle="-")
plt.plot(x, quiS, label = "quiS", linestyle="-")
plt.plot(x, quiO, label = "quiO", linestyle="-")
plt.plot(x, quoiO, label = "quoiO", linestyle="-")
plt.legend()
plt.show()

# %%
# in situ line

# create data
x = ['late 1800', 'early 1900', '1970s', '2010s']

# y axes
comment = [0, 0, 4, 32]
où = [0, 0, 24, 76]
quand = [0, 0, 19, 48]
quiS = [0, 0, 0, 6]
quiO = [0, 0, 26, 70]
quoiO = [0, 0, 39, 96]
  
# plot lines
plt.plot(x, comment, label = "comment", linestyle="-")
plt.plot(x, où, label = "où", linestyle="-")
plt.plot(x, quand, label = "quand", linestyle="-")
plt.plot(x, quiS, label = "quiS", linestyle="-")
plt.plot(x, quiO, label = "quiO", linestyle="-")
plt.plot(x, quoiO, label = "quoiO", linestyle="-")
plt.legend()
plt.show()
